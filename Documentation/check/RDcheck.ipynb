# %%
import os
os.chdir('..')

import numpy as np
# import FT as FT


import matplotlib
#matplotlib.use('WebAgg')
#matplotlib.use('Qt4Cairo')
#matplotlib.use('Qt5Cairo')
matplotlib.use('nbAgg')
import matplotlib.pyplot as plt

plt.rcParams['font.family']='serif'
plt.rcParams['font.size']=14
plt.rcParams['mathtext.fontset']='stix'
os.chdir('check')

# %%
Lattice_theta=np.loadtxt('./1606.07494/fa_vs_theta.dat')#data from  1606.07494


Lattice_Tosc=np.loadtxt('./1606.07494/fa_vs_Tosc.dat')#data from  1606.07494


AxionCosmoRev=np.loadtxt('./0910.1066/theta_vs_fa.dat')#data from 0910.1066  
AxionCosmoRev_approx=np.loadtxt('./0910.1066/theta_vs_fa_approx.dat')#data from 0910.1066 (WKB)  




# _ = np.load('../results/RDAxion_data/RD_Axion.npy')
# _cc=_[:,9]>0.12*0.99
# _cc=np.logical_and(_cc,_[:,9]<0.12*1.01)

# Mine=_[_cc][:,[0,1,8]]
# Mine_approx=np.load('../results/RDAxion_data/RD_Axion_analytical_approx.npy')[:,[0,1]]

# %%
if True:
    fig=plt.figure(figsize=(9,4))
    fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.0,hspace=0.25)
    sub = fig.add_subplot(1,1,1)
    
#     sub.plot(Mine[:,1],Mine[:,0],linestyle='-',linewidth=2.5,alpha=1,c='xkcd:red',label=r"Mine")
    sub.plot(Lattice_theta[:,0],Lattice_theta[:,1],linestyle=(1,(2,5)),linewidth=2,alpha=1,c='xkcd:black',label=r"1606.07494")

    sub.plot(AxionCosmoRev[:,1],AxionCosmoRev[:,0],linewidth=2,alpha=1,linestyle=(1,(4,10)),c='xkcd:blue',label=r"0910.1066")
    
    
    sub.set_xlabel(r'$f_\alpha ~[{\rm GeV}]$')
    sub.xaxis.set_label_coords(0.5, -0.1) 
    sub.set_ylabel(r'$ \theta_{\rm ini}$')
    sub.yaxis.set_label_coords(-0.1,0.5) 
    sub.set_yscale('log')
    sub.set_xscale('log')
    
    sub.set_xlim(1e10,1e20)
    sub.set_ylim(1e-5,10)

    sub.legend(bbox_to_anchor=(0.02, 0.02),borderaxespad=0., 
           borderpad=0,ncol=1,loc='lower left',fontsize=10,framealpha=0)

    
    fig.savefig('RD_fa_vs_theta_i_check.pdf',bbox_inches='tight')

    fig.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
if True:
    fig=plt.figure(figsize=(9,4))
    fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.0,hspace=0.25)
    sub = fig.add_subplot(1,1,1)
    
#     sub.plot(Mine_approx[:,1],Mine_approx[:,0],linestyle='-',linewidth=2.5,alpha=1,c='xkcd:red',label=r"Mine")
    sub.plot(AxionCosmoRev_approx[:,1],AxionCosmoRev_approx[:,0],linestyle=(1,(4,10)),linewidth=2,alpha=1,c='xkcd:blue',label=r"0910.1066")

    
    
    sub.set_xlabel(r'$f_\alpha ~[{\rm GeV}]$')
    sub.xaxis.set_label_coords(0.5, -0.1) 
    sub.set_ylabel(r'$ \theta_{\rm ini}$')
    sub.yaxis.set_label_coords(-0.1,0.5) 
    sub.set_yscale('log')
    sub.set_xscale('log')
    
    sub.set_xlim(1e11,1e19)
    sub.set_ylim(1e-5,4)

    sub.legend(bbox_to_anchor=(0.02, 0.02),borderaxespad=0., 
           borderpad=0,ncol=1,loc='lower left',fontsize=10,framealpha=0)
    
    fig.savefig('RD_fa_vs_theta_i_check_WKB.pdf',bbox_inches='tight')

    fig.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
if True:
    fig=plt.figure(figsize=(9,4))
    fig.subplots_adjust(bottom=0.15, left=0.15, top = 0.9, right=0.9,wspace=0.0,hspace=0.25)
    sub = fig.add_subplot(1,1,1)
    
#     sub.plot(Mine[:,1],Mine[:,2],linestyle='-',linewidth=2,alpha=1,c='xkcd:red',label=r"Mine")
    sub.plot(Lattice_Tosc[:,0],Lattice_Tosc[:,1],linestyle='--',linewidth=2,alpha=1,c='xkcd:black',label=r"1606.07494")
    
    
    sub.set_xlabel(r'$f_\alpha ~[{\rm GeV}]$')
    sub.xaxis.set_label_coords(0.5, -0.1) 
    sub.set_ylabel(r'$ T_{\rm osc} ~[{\rm GeV}]$')
    sub.yaxis.set_label_coords(-0.1,0.5) 
    sub.set_yscale('log')
    sub.set_xscale('log')
    
    sub.set_xlim(1e9,1e19)
    sub.set_ylim(1e-2,10)
    
    
    sub.legend(bbox_to_anchor=(0.02, 0.02),borderaxespad=0., 
           borderpad=0,ncol=1,loc='lower left',fontsize=10,framealpha=0)

    
    fig.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
